# %%
# 19.09.25
# # None type
None a not is None
# Answer is true or fase 
# Инкарсуляция (внутри ячейки СВОЙСТВА МЕТОДЫ)
# Example   
x=2+3j 
x.real = k 
print (k)
x.imag = k 
print (k) 
# Списки
a = [2, 5, 3.7, True]
print (a, type (a))
print (a[1])
# введение новых членов списка
b = [] 
b += [4]
b += b + [2.5]
print (b)
# умнжение в списках
c = [0]*10
print (c) 
# методы списков 

# APPEND
b = ['Hi'] 
b.append(4)
b.append(5)
print (b)

# INDEX
b = [1, 3, 4, 5, 7, 8] 
print (b.index(5))

# INSERT
# 19.09.25
# # None type
None a not is None
# Answer is true or fase 
# Инкарсуляция (внутри ячейки СВОЙСТВА МЕТОДЫ)
# Example   
x=2+3j 
x.real = k 
print (k)
x.imag = k 
print (k) 
# Списки
a = [2, 5, 3.7, True]
print (a, type (a))
print (a[1])
# введение новых членов списка
b = [] 
b += [4]
b += b + [2.5]
print (b)
# умнжение в списках
c = [0]*10
print (c) 

# МЕТОДЫ СПИСКОВ

# APPEND
b = ['Hi'] 
b.append(4)
b.append(5)
print (b)

# INDEX
b = [1, 3, 4, 5, 7, 8] 
print (b.index(5))

# INSERT
b = [1, 3, 4, 5, 7, 8] 
b.insert(3, 4)
print (b)

# COPY 
c = b.copy()
b[2] = 89
print (b)
print (c) 

# Срезы списков
#lst[START:STOP:STEP]
b = [1, 3, 4, 5, 7, 8] 
print (b[2:5:1])

b = [1, 3, 4, 5, 7, 8] 
b[2:3] = [0, 0]
print (b)

#  С функцией step всё очевидно (но бывает отрицательным)

# ienght

#  КОРТЕЖ (tuple) или неизменяемый список. Синтаксический сахар: можно не писать круглые скобки
e = (1, 2, 3, 0, 9, 3, 7, 3, 7, 9, 3, 9)
print (e, type(e))
print(e.index(9))
e[3] = 0


# Запаковывание и распаковывание картежа
n=9
name= 'Фтор'
am= 18.998
t = n, name, am
t

m, elem, mass = t
print(mass)


# циклы while
i=0
while i<3:
    i+=1
    print(i)

# циклы for
i=0
for i in range(300):
    print('хуй')

# циклы с break
i=0
for i in range(300):
    print('хуй')
